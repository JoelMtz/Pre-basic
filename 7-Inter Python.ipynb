# %%
# Print the last item from year and pop
print(year[-1])
print(pop[-1])
# Out:
# 2100
# 10.85

# %% [markdown]
# ### Line plot

# %%
# Make a line plot: year on the x-axis, pop on the y-axis
plt.plot(year,pop)

# Display the plot with plt.show()
plt.show()

# %%
year1 = [12,13,14,15,16,18,18,20,24,26]
pop1=[2,5,6,7,8,11,14,14,15,16]

# %% [markdown]
# ### Scatter plot

# %%
# Change the line plot below to a scatter plot
plt.scatter(year1, pop1)

# Put the x-axis on a logarithmic scale
plt.xscale('log')

# Show plot
plt.show()

# %% [markdown]
# ### histogram

# %%
# Create histogram of pop data
plt.hist(pop)

# Display histogram
plt.show()

# %%
# Build histogram with 5 bins
plt.hist(pop,bins=5)

# Show and clean up plot
plt.show()
plt.clf()

# Build histogram with 20 bins
plt.hist(pop,bins=20)

# Show and clean up again
plt.show()
plt.clf()

# %% [markdown]
# ## Labels

# %%
# Basic scatter plot, log scale
plt.scatter(year1, pop1)
plt.xscale('log') 

# Strings
xlab = 'agnos'
ylab = 'Puestos'
title = 'Crecimiento empleos'

# Add axis labels
plt.xlabel(xlab)
plt.ylabel(ylab)

# Add title
plt.title(title)

# After customizing, display the plot
plt.show()

# %%
# abrir una base de datos
base = pd.read_csv("gapminder.csv")

# %%
base.head(2)
# Out:
#    Unnamed: 0      country  year  population    cont  life_exp      gdp_cap
# 0          11  Afghanistan  2007  31889923.0    Asia    43.828   974.580338
# 1          23      Albania  2007   3600523.0  Europe    76.423  5937.029526

# %%
# Basic scatter plot, log scale
# para llamar a dos variables de la misma de base de dts necesito poner la base y despues un punto
plt.scatter(base.gdp_cap, base.life_exp)
plt.xscale('log') 

# Strings
xlab = 'GDP per Capita [in USD]'
ylab = 'Life Expectancy [in years]'
title = 'World Development in 2007'

# Add axis labels
plt.xlabel(xlab)
plt.ylabel(ylab)

# Add title
plt.title(title)

# After customizing, display the plot
plt.show()

# %%
# Scatter plot
plt.scatter(base.gdp_cap, base.life_exp)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')

# Definition of tick_val and tick_lab
tick_val = [1000, 10000, 100000]
tick_lab = ['1k', '10k', '100k']

# Adapt the ticks on the x-axis
plt.xticks(tick_val,tick_lab)

# After customizing, display the plot
plt.show()

# %%
pop2= [2.53,
 2.57,
 2.62,
 2.67,
 2.71,
 2.76,
 2.81,
 2.86,
 2.92,
 2.97,
 3.03,
 3.08,
 3.14,
 3.2,
 3.26,
 3.33,
 3.4,
 3.47,
 3.54,
 3.62,
 3.69,
 3.77,
 3.84,
 3.92,
 4.0,
 4.07,
 4.15,
 4.22,
 4.3,
 4.37,
 4.45,
 4.53,
 4.61,
 4.69,
 4.78,
 4.86,
 4.95,
 5.05,
 5.14,
 5.23,
 5.32,
 5.41,
 5.49,
 5.58,
 5.66,
 5.74,
 5.82,
 5.9,
 5.98,
 6.05,
 6.13,
 6.2,
 6.28,
 6.36,
 6.44,
 6.51,
 6.59,
 6.67,
 6.75,
 6.83,
 6.92,
 7.0,
 7.08,
 7.16,
 7.24,
 7.32,
 7.4,
 7.48,
 7.56,
 7.64,
 7.72,
 7.79,
 7.87,
 7.94,
 8.01,
 8.08,
 8.15,
 8.22,
 8.29,
 8.36,
 8.42,
 8.49,
 8.56,
 8.62,
 8.68,
 8.74,
 8.8,
 8.86,
 8.92,
 8.98,
 9.04,
 9.09,
 9.15,
 9.2,
 9.26,
 9.31,
 9.36,
 9.41,
 9.46,
 9.5,
 9.55,
 9.6,
 9.64,
 9.68,
 9.73,
 9.77,
 9.81,
 9.85,
 9.88,
 9.92,
 9.96,
 9.99,
 10.03,
 10.06,
 10.09,
 10.13,
 10.16,
 10.19,
 10.22,
 10.25,
 10.28,
 10.31,
 10.33,
 10.36,
 10.38,
 10.41,
 10.43,
 10.46,
 10.48,
 10.5,
 10.52,
 10.55,
 10.57,
 10.59,
 10.61,
 10.63,
 10.65,
 10.66,
 10.68,
 10.7,
 10.72,
 10.73]

# %%
# Import numpy as np
import numpy as np

# Store pop as a numpy array: np_pop
# para poder hacerlo array solo necesitamos la variable y no la base
np_pop = np.array(pop2)
type(np_pop)
print(np_pop)
# Out:
# [ 2.53  2.57  2.62  2.67  2.71  2.76  2.81  2.86  2.92  2.97  3.03  3.08
#   3.14  3.2   3.26  3.33  3.4   3.47  3.54  3.62  3.69  3.77  3.84  3.92
#   4.    4.07  4.15  4.22  4.3   4.37  4.45  4.53  4.61  4.69  4.78  4.86
#   4.95  5.05  5.14  5.23  5.32  5.41  5.49  5.58  5.66  5.74  5.82  5.9
#   5.98  6.05  6.13  6.2   6.28  6.36  6.44  6.51  6.59  6.67  6.75  6.83
#   6.92  7.    7.08  7.16  7.24  7.32  7.4   7.48  7.56  7.64  7.72  7.79
#   7.87  7.94  8.01  8.08  8.15  8.22  8.29  8.36  8.42  8.49  8.56  8.62
#   8.68  8.74  8.8   8.86  8.92  8.98  9.04  9.09  9.15  9.2   9.26  9.31
#   9.36  9.41  9.46  9.5   9.55  9.6   9.64  9.68  9.73  9.77  9.81  9.85
#   9.88  9.92  9.96  9.99 10.03 10.06 10.09 10.13 10.16 10.19 10.22 10.25
#  10.28 10.31 10.33 10.36 10.38 10.41 10.43 10.46 10.48 10.5  10.52 10.55
#  10.57 10.59 10.61 10.63 10.65 10.66 10.68 10.7  10.72 10.73]

# %%
base
# Out:
#      Unnamed: 0             country  year  population      cont  life_exp  \
# 0            11         Afghanistan  2007  31889923.0      Asia    43.828
# 1            23             Albania  2007   3600523.0    Europe    76.423
# 2            35             Algeria  2007  33333216.0    Africa    72.301
# 3            47              Angola  2007  12420476.0    Africa    42.731
# 4            59           Argentina  2007  40301927.0  Americas    75.320
# ..          ...                 ...   ...         ...       ...       ...
# 137        1655             Vietnam  2007  85262356.0      Asia    74.249
# 138        1667  West Bank and Gaza  2007   4018332.0      Asia    73.422
# 139        1679         Yemen, Rep.  2007  22211743.0      Asia    62.698
# 140        1691              Zambia  2007  11746035.0    Africa    42.384
# 141        1703            Zimbabwe  2007  12311143.0    Africa    43.487
#
#           gdp_cap
# 0      974.580338
# 1     5937.029526
# 2     6223.367465
# ...

# %%
# Double np_pop
np_pop = np_pop * 2
print(np_pop)
# Out:
# [ 5.06  5.14  5.24  5.34  5.42  5.52  5.62  5.72  5.84  5.94  6.06  6.16
#   6.28  6.4   6.52  6.66  6.8   6.94  7.08  7.24  7.38  7.54  7.68  7.84
#   8.    8.14  8.3   8.44  8.6   8.74  8.9   9.06  9.22  9.38  9.56  9.72
#   9.9  10.1  10.28 10.46 10.64 10.82 10.98 11.16 11.32 11.48 11.64 11.8
#  11.96 12.1  12.26 12.4  12.56 12.72 12.88 13.02 13.18 13.34 13.5  13.66
#  13.84 14.   14.16 14.32 14.48 14.64 14.8  14.96 15.12 15.28 15.44 15.58
#  15.74 15.88 16.02 16.16 16.3  16.44 16.58 16.72 16.84 16.98 17.12 17.24
#  17.36 17.48 17.6  17.72 17.84 17.96 18.08 18.18 18.3  18.4  18.52 18.62
#  18.72 18.82 18.92 19.   19.1  19.2  19.28 19.36 19.46 19.54 19.62 19.7
#  19.76 19.84 19.92 19.98 20.06 20.12 20.18 20.26 20.32 20.38 20.44 20.5
#  20.56 20.62 20.66 20.72 20.76 20.82 20.86 20.92 20.96 21.   21.04 21.1
#  21.14 21.18 21.22 21.26 21.3  21.32 21.36 21.4  21.44 21.46]

# %%
# agregar un elemento a un dataframe
base['np_pop']= np_pop
base
# Out:
#      Unnamed: 0             country  year  population      cont  life_exp  \
# 0            11         Afghanistan  2007  31889923.0      Asia    43.828
# 1            23             Albania  2007   3600523.0    Europe    76.423
# 2            35             Algeria  2007  33333216.0    Africa    72.301
# 3            47              Angola  2007  12420476.0    Africa    42.731
# 4            59           Argentina  2007  40301927.0  Americas    75.320
# ..          ...                 ...   ...         ...       ...       ...
# 137        1655             Vietnam  2007  85262356.0      Asia    74.249
# 138        1667  West Bank and Gaza  2007   4018332.0      Asia    73.422
# 139        1679         Yemen, Rep.  2007  22211743.0      Asia    62.698
# 140        1691              Zambia  2007  11746035.0    Africa    42.384
# 141        1703            Zimbabwe  2007  12311143.0    Africa    43.487
#
#           gdp_cap  np_pop
# 0      974.580338    5.06
# ...

# %%
# Update: set s argument to np_pop
plt.scatter(base.gdp_cap, base.life_exp, s = np_pop)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000, 10000, 100000],['1k', '10k', '100k'])

# Display the plot
plt.show()

# %%
# Specify c and alpha inside plt.scatter()
plt.scatter(x = base.gdp_cap, y = base.life_exp, s = np.array(pop2) * 2,  alpha=0.8)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000,10000,100000], ['1k','10k','100k'])

# Show the plot
plt.show()

# %%
# Scatter plot
plt.scatter(x = base.gdp_cap, y = base.life_exp, s = np.array(pop2) * 2,  alpha = 0.8)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000,10000,100000], ['1k','10k','100k'])

# Additional customizations
plt.text(1550, 71, 'India')
plt.text(5700, 80, 'China')

# Add grid() call
plt.grid(True)

# Show the plot
plt.show()
